# %%
import pandas as pd
import matplotlib as mpl
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install geopandas
# !apt install gdal-bin python-gdal python3-gdal
# !apt install python3-rtree 
import geopandas as gpd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: geopandas in /usr/local/lib/python3.9/dist-packages (0.12.2)
# Requirement already satisfied: shapely>=1.7 in /usr/local/lib/python3.9/dist-packages (from geopandas) (2.0.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from geopandas) (23.0)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from geopandas) (1.4.4)
# Requirement already satisfied: fiona>=1.8 in /usr/local/lib/python3.9/dist-packages (from geopandas) (1.9.2)
# Requirement already satisfied: pyproj>=2.6.1.post1 in /usr/local/lib/python3.9/dist-packages (from geopandas) (3.4.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.9/dist-packages (from fiona>=1.8->geopandas) (22.2.0)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.9/dist-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.9/dist-packages (from fiona>=1.8->geopandas) (2022.12.7)
# Requirement already satisfied: munch>=2.3.2 in /usr/local/lib/python3.9/dist-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.9/dist-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.9/dist-packages (from fiona>=1.8->geopandas) (6.1.0)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.9/dist-packages (from fiona>=1.8->geopandas) (8.1.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0.0->geopandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0.0->geopandas) (1.22.4)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from munch>=2.3.2->fiona>=1.8->geopandas) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata->fiona>=1.8->geopandas) (3.15.0)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Package python-gdal is not available, but is referred to by another package.
# This may mean that the package is missing, has been obsoleted, or
# is only available from another source
# However the following packages replace it:
#   gdal-bin
#
# E: Package 'python-gdal' has no installation candidate
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python3-rtree is already the newest version (0.9.4-1).
# 0 upgraded, 0 newly installed, 0 to remove and 23 not upgraded.

# %%
#downloading shapefile of Ukraine
# !wget https://biogeo.ucdavis.edu/data/gadm3.6/shp/gadm36_UKR_shp.zip
# !unzip gadm36_UKR_shp.zip
# Out:
# --2023-03-22 23:58:41--  https://biogeo.ucdavis.edu/data/gadm3.6/shp/gadm36_UKR_shp.zip
# Resolving biogeo.ucdavis.edu (biogeo.ucdavis.edu)... 128.120.228.172
# Connecting to biogeo.ucdavis.edu (biogeo.ucdavis.edu)|128.120.228.172|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://data.biogeo.ucdavis.edu/data/gadm3.6/shp/gadm36_UKR_shp.zip [following]
# --2023-03-22 23:58:42--  https://data.biogeo.ucdavis.edu/data/gadm3.6/shp/gadm36_UKR_shp.zip
# Resolving data.biogeo.ucdavis.edu (data.biogeo.ucdavis.edu)... 128.120.228.172
# Connecting to data.biogeo.ucdavis.edu (data.biogeo.ucdavis.edu)|128.120.228.172|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2238196 (2.1M) [application/zip]
# Saving to: ‘gadm36_UKR_shp.zip.1’
#
# gadm36_UKR_shp.zip. 100%[===================>]   2.13M  4.25MB/s    in 0.5s
#
# 2023-03-22 23:58:43 (4.25 MB/s) - ‘gadm36_UKR_shp.zip.1’ saved [2238196/2238196]
#
# Archive:  gadm36_UKR_shp.zip
# replace gadm36_UKR_0.cpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#  extracting: gadm36_UKR_0.cpg
# replace gadm36_UKR_0.dbf? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: gadm36_UKR_0.dbf
# replace gadm36_UKR_0.prj? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: gadm36_UKR_0.prj
#   inflating: gadm36_UKR_0.shp
#   inflating: gadm36_UKR_0.shx
#  extracting: gadm36_UKR_1.cpg
#   inflating: gadm36_UKR_1.dbf
#   inflating: gadm36_UKR_1.prj
#   inflating: gadm36_UKR_1.shp
#   inflating: gadm36_UKR_1.shx
#  extracting: gadm36_UKR_2.cpg
#   inflating: gadm36_UKR_2.dbf
#   inflating: gadm36_UKR_2.prj
#   inflating: gadm36_UKR_2.shp
#   inflating: gadm36_UKR_2.shx
#   inflating: license.txt

# %%
map = gpd.read_file('/content/gadm36_UKR_1.shp')
map = map.set_geometry('geometry')
map.head(10)
# Out:
#   GID_0   NAME_0     GID_1            NAME_1  \
# 0   UKR  Ukraine   UKR.1_1          Cherkasy
# 1   UKR  Ukraine   UKR.2_1         Chernihiv
# 2   UKR  Ukraine   UKR.3_1        Chernivtsi
# 3   UKR  Ukraine   UKR.4_1            Crimea
# 4   UKR  Ukraine   UKR.5_1   Dnipropetrovs'k
# 5   UKR  Ukraine   UKR.6_1          Donets'k
# 6   UKR  Ukraine   UKR.7_1  Ivano-Frankivs'k
# 7   UKR  Ukraine   UKR.8_1           Kharkiv
# 8   UKR  Ukraine   UKR.9_1           Kherson
# 9   UKR  Ukraine  UKR.10_1    Khmel'nyts'kyy
#
#                                            VARNAME_1  NL_NAME_1  \
# 0  Cherkas'ka Oblast'|Cherkasskaya Oblast'|Cherkassy        NaN
# 1                              Chernigov|Tschernigow        NaN
# 2  Chernivets'ka Oblast'|Chernovitskaya Oblast'|C...        NaN
# 3  Crimée|Criméia|Krim|Krymskaya Respublika|Respu...        NaN
# 4    Dnipropetrovsk|Dniepropietrovsk|Dnjepropetrowsk        NaN
# 5          Donetsk|Donetskaya Oblast'|Donezk|Stalino        NaN
# 6  Ivano-Frankovsk|Ivano-Frankovskaya Oblast'|Sta...        NaN
# 7                     Charkow|Jarkov|Karkov|Khar'kov        NaN
# 8                        Cherson|Khersons'ka Oblast'        NaN
# 9  Khmelnitsky|Khmelnytskyi|Chmelnizkij|Hmelnicki...        NaN
#
#                 TYPE_1            ENGTYPE_1  CC_1 HASC_1  \
# 0              Oblast'               Region   NaN  UA.CK
# 1              Oblast'               Region   NaN  UA.CH
# 2              Oblast'               Region   NaN  UA.CV
# 3  Autonomous Republic  Autonomous Republic   NaN  UA.KR
# 4              Oblast'               Region   NaN  UA.DP
# 5              Oblast'               Region   NaN  UA.DT
# 6              Oblast'               Region   NaN  UA.IF
# 7              Oblast'               Region   NaN  UA.KK
# 8              Oblast'               Region   NaN  UA.KS
# 9              Oblast'               Region   NaN  UA.KM
#
#                                             geometry
# 0  POLYGON ((31.32614 48.74507, 31.31716 48.74512...
# 1  POLYGON ((33.09283 50.50966, 33.09261 50.49788...
# 2  POLYGON ((24.93280 47.72794, 24.93301 47.72995...
# 3  MULTIPOLYGON (((33.79291 44.39153, 33.79465 44...
# 4  POLYGON ((33.93176 47.48407, 33.92332 47.49026...
# 5  MULTIPOLYGON (((37.67542 47.08208, 37.67542 47...
# 6  POLYGON ((24.48985 48.29008, 24.47929 48.30110...
# 7  POLYGON ((36.73418 48.61828, 36.71661 48.61870...
# 8  MULTIPOLYGON (((31.96903 46.20319, 31.96903 46...
# 9  POLYGON ((26.43747 48.53564, 26.43671 48.54154...

# %%
#reading into a dataframe
ukraine_map = gpd.read_file('/content/gadm36_UKR_1.shp')
ukraine_map.plot(facecolor="none", figsize=(12, 12))
# Out:
# <Axes: >

# %%
ukraine_map.columns
# Out:
# Index(['GID_0', 'NAME_0', 'GID_1', 'NAME_1', 'VARNAME_1', 'NL_NAME_1',
#        'TYPE_1', 'ENGTYPE_1', 'CC_1', 'HASC_1', 'geometry'],
#       dtype='object')

# %%
ukraine_map['NAME_1'] = ukraine_map['NAME_1'].replace(["Kiev"], "Kyiv")
# ukraine_map['NAME_1'] = ukraine_map['NAME_1'].replace(["Kiev City"], "Kyiv")
ukraine_map['NAME_1'] = ukraine_map['NAME_1'].replace(["L'viv"], "Lviv")
ukraine_map['NAME_1'] = ukraine_map['NAME_1'].replace(["Dnipropetrovs'k"], "Dnipropetrovsk")
ukraine_map['NAME_1'] = ukraine_map['NAME_1'].replace(["Donets'k"], "Donetsk")
ukraine_map['NAME_1'] = ukraine_map['NAME_1'].replace(["Khmel'nyts'kyy"], "Khmelnytskyi")
ukraine_map['NAME_1'] = ukraine_map['NAME_1'].replace(["Luhans'k"], "Luhansk")
ukraine_map['NAME_1'] = ukraine_map['NAME_1'].replace(["Ternopil'"], "Ternopil")
ukraine_map['NAME_1'] = ukraine_map['NAME_1'].replace(["Mykolayiv'"], "Mykolaiv")
ukraine_map['NAME_1'] = ukraine_map['NAME_1'].replace(["Odessa"], "Odesa")
ukraine_map['NAME_1'] = ukraine_map['NAME_1'].replace(["Vinnytsya"], "Vinnytsia")
ukraine_map['NAME_1'] = ukraine_map['NAME_1'].replace(["Zaporizhzhya'"], "Zaporizhzhia")
ukraine_map['NAME_1'] = ukraine_map['NAME_1'].replace(["Transcarpathia"], "Zakarpattia")

# %%
df_final = pd.read_csv('/content/drive/MyDrive/112_Project_DataV2 (1).0')
df_final_pkl = pd.read_pickle('/content/drive/MyDrive/112_Project_DataV2.0.pkl')
df_final_pkl
# Out:
#            date             city   region      lat      lng  \
# 0    2022-03-02        [Kharkiv]  Kharkiv  50.0000  36.2292
# 1    2022-03-03            [nan]     Kyiv  50.4500  30.5236
# 2    2022-03-02  [Severodonetsk]  Donetsk  48.9482  38.4879
# 3    2022-03-03           [Kyiv]     Kyiv  50.4500  30.5236
# 4    2022-03-02        [Kharkiv]  Kharkiv  50.0000  36.2292
# ...         ...              ...      ...      ...      ...
# 8789 2023-02-15            [nan]  Donetsk  48.0089  37.8042
# 8790 2023-02-15            [nan]  Kharkiv  50.0000  36.2292
# 8791 2023-02-15            [nan]  Kharkiv  50.0000  36.2292
# 8792 2023-02-15       [Pokrovsk]  Donetsk  48.2833  37.1833
# 8793 2023-02-15            [nan]  Donetsk  48.0089  37.8042
#
#                                                 content
# 0                        Kharkiv Missile striked school
# 1     Hatne Kyiv region due to a powerful airstrike ...
# 2     Donetsk region Severodonetsk Kindergarten was ...
# 3                       Kyiv russian cruise missile TAG
# 4        Kharkiv Consequences of airstrike on city hall
# ...                                                 ...
# 8789  Donetsk region Residential high-rise buildings...
# 8790  Kharkiv region Private houses, households dama...
# 8791  Kharkiv region Private houses, households dama...
# 8792  Pokrovsk Donetsk region Residential high-rise ...
# 8793  Chasiv Yar Donetsk region Humanitarian headqua...
#
# [8794 rows x 6 columns]

# %%
df_final_pkl["region"].unique()
# Out:
# array(['Kharkiv', 'Kyiv', 'Donetsk', nan, 'Mykolaiv', 'Chernihiv', 'Sumy',
#        'Zhytomyr', 'Ukraine', 'Luhansk', 'Odesa', 'Kherson', 'Lviv',
#        'Vinnytsia', 'Dnipropetrovsk', 'Volyn', 'Poltava', 'Zaporizhzhia',
#        'Rivne', 'Khmelnytskyi', 'Ternopil', 'Zakarpattia', 'Kirovohrad'],
#       dtype=object)

# %%
pkl_cong = df_final_pkl.groupby('region').count()
pkl_cong['region'] = pkl_cong.index
pkl_cong = pkl_cong[['region', 'date']]
pkl_cong['count'] = pkl_cong['date']
pkl_cong = pkl_cong[['count', 'region']]

# %%
pkl_cong = pkl_cong.reset_index(drop=True)
pkl_cong
# Out:
#     count          region
# 0     149       Chernihiv
# 1     486  Dnipropetrovsk
# 2    2417         Donetsk
# 3    1472         Kharkiv
# 4     381         Kherson
# 5      10    Khmelnytskyi
# 6      12      Kirovohrad
# 7     850            Kyiv
# 8     410         Luhansk
# 9      41            Lviv
# 10    670        Mykolaiv
# 11    126           Odesa
# 12     29         Poltava
# 13     10           Rivne
# 14    349            Sumy
# 15      3        Ternopil
# 16     57         Ukraine
# 17     17       Vinnytsia
# 18      4           Volyn
# 19      1     Zakarpattia
# 20    704    Zaporizhzhia
# 21     39        Zhytomyr

# %%
df_final_pkl['geometry'] = gpd.points_from_xy(df_final_pkl['lng'], df_final_pkl['lat'])

# %%
import matplotlib.pyplot as plt

# %%
new_df = pd.DataFrame()
new_df['geometry'] = df_final_pkl['geometry']

geo_df = gpd.GeoDataFrame(df_final_pkl)

fig, ax = plt.subplots(1, 1, figsize=(12, 12))

# ax = ukraine_map.plot(facecolor="none", figsize=(12,12))
ukraine_map.plot(facecolor="none", ax=ax)
geo_df.plot(ax=ax)
# Out:
# <Axes: >

# %%
df_final_pkl["region"].isna().sum()
# Out:
# 557

# %%
ukraine_map["region"] = ukraine_map["NAME_1"]
ukraine_map_merged = ukraine_map.merge(pkl_cong, on="region")

# %%
ukraine_map_merged
# Out:
#    GID_0   NAME_0     GID_1          NAME_1  \
# 0    UKR  Ukraine   UKR.2_1       Chernihiv
# 1    UKR  Ukraine   UKR.5_1  Dnipropetrovsk
# 2    UKR  Ukraine   UKR.6_1         Donetsk
# 3    UKR  Ukraine   UKR.8_1         Kharkiv
# 4    UKR  Ukraine   UKR.9_1         Kherson
# 5    UKR  Ukraine  UKR.10_1    Khmelnytskyi
# 6    UKR  Ukraine  UKR.12_1            Kyiv
# 7    UKR  Ukraine  UKR.13_1      Kirovohrad
# 8    UKR  Ukraine  UKR.14_1            Lviv
# 9    UKR  Ukraine  UKR.15_1         Luhansk
# 10   UKR  Ukraine  UKR.17_1           Odesa
# 11   UKR  Ukraine  UKR.18_1         Poltava
# 12   UKR  Ukraine  UKR.19_1           Rivne
# 13   UKR  Ukraine  UKR.21_1            Sumy
# 14   UKR  Ukraine  UKR.22_1        Ternopil
# 15   UKR  Ukraine  UKR.23_1     Zakarpattia
# 16   UKR  Ukraine  UKR.24_1       Vinnytsia
# 17   UKR  Ukraine  UKR.25_1           Volyn
# 18   UKR  Ukraine  UKR.27_1        Zhytomyr
#
#                                             VARNAME_1  NL_NAME_1   TYPE_1  \
# 0                               Chernigov|Tschernigow        NaN  Oblast'
# 1     Dnipropetrovsk|Dniepropietrovsk|Dnjepropetrowsk        NaN  Oblast'
# 2           Donetsk|Donetskaya Oblast'|Donezk|Stalino        NaN  Oblast'
# 3                      Charkow|Jarkov|Karkov|Khar'kov        NaN  Oblast'
# 4                         Cherson|Khersons'ka Oblast'        NaN  Oblast'
# 5   Khmelnitsky|Khmelnytskyi|Chmelnizkij|Hmelnicki...        NaN  Oblast'
# 6   Kiev Oblast|Kiew|Kijew|Kiiv|Kijev|Kiyev|Kyiv|K...        NaN  Oblast'
# 7                  Kirovograd|Kirovogradskaya Oblast'        NaN  Oblast'
# 8          Lemberg|Llvov|L'vov|Lwow|L'vivs'ka Oblast'        NaN  Oblast'
# 9    Luhansk|Lugansk|Luhans'ka Oblast'|Voroshilovgrad        NaN  Oblast'
# 10            Odesa|Odes'ka Oblast'|Odesskaya Oblast'        NaN  Oblast'
# 11                                                NaN        NaN  Oblast'
# 12        Rovno|Rivnens'ka Oblast'|Rovenskaya Oblast'        NaN  Oblast'
# 13                                                NaN        NaN  Oblast'
# 14                                 Ternopol|Ternopol'        NaN  Oblast'
# 15  Transcarpathian|Zakarpattia|Ruthenia|Zakarpats...        NaN  Oblast'
# 16  Vinnytsia|Vinnitskaya Oblast'|Vinnyts'ka Oblas...        NaN  Oblast'
# 17  Volhynia|Volyns'ka Oblast'|Volynskaya Oblast'|...        NaN  Oblast'
# 18    Zhitomir|Jitomir|Shitomir|Zhitomirskaya Oblast'        NaN  Oblast'
#
#    ENGTYPE_1  CC_1 HASC_1                                           geometry  \
# 0     Region   NaN  UA.CH  POLYGON ((33.09283 50.50966, 33.09261 50.49788...
# 1     Region   NaN  UA.DP  POLYGON ((33.93176 47.48407, 33.92332 47.49026...
# 2     Region   NaN  UA.DT  MULTIPOLYGON (((37.67542 47.08208, 37.67542 47...
# 3     Region   NaN  UA.KK  POLYGON ((36.73418 48.61828, 36.71661 48.61870...
# 4     Region   NaN  UA.KS  MULTIPOLYGON (((31.96903 46.20319, 31.96903 46...
# 5     Region   NaN  UA.KM  POLYGON ((26.43747 48.53564, 26.43671 48.54154...
# 6     Region   NaN  UA.KV  POLYGON ((29.74569 49.24075, 29.72713 49.25809...
# 7     Region   NaN  UA.KH  POLYGON ((31.82397 47.79166, 31.83274 47.79161...
# 8     Region   NaN  UA.LV  MULTIPOLYGON (((23.96410 50.41843, 23.96423 50...
# 9     Region   NaN  UA.LH  POLYGON ((39.91058 48.16798, 39.90993 48.16432...
# 10    Region   NaN  UA.OD  MULTIPOLYGON (((30.20708 45.25764, 30.20708 45...
# 11    Region   NaN  UA.PL  POLYGON ((35.51211 49.55266, 35.46757 49.55336...
# 12    Region   NaN  UA.RV  POLYGON ((26.30246 50.20480, 26.29387 50.19846...
# 13    Region   NaN  UA.SM  POLYGON ((34.96434 50.14548, 34.94647 50.14563...
# 14    Region   NaN  UA.TP  POLYGON ((26.20062 48.91127, 26.20966 48.91165...
# 15    Region   NaN  UA.ZK  POLYGON ((23.89934 47.94503, 23.89867 47.94472...
# 16    Region   NaN  UA.VI  POLYGON ((29.96737 48.61654, 29.96781 48.60485...
# 17    Region   NaN  UA.VO  POLYGON ((24.58838 50.44717, 24.58535 50.47087...
# 18    Region   NaN  UA.ZT  POLYGON ((29.46955 49.81223, 29.46984 49.80634...
#
#             region  count
# 0        Chernihiv    149
# 1   Dnipropetrovsk    486
# 2          Donetsk   2417
# 3          Kharkiv   1472
# 4          Kherson    381
# 5     Khmelnytskyi     10
# 6             Kyiv    850
# 7       Kirovohrad     12
# 8             Lviv     41
# 9          Luhansk    410
# 10           Odesa    126
# 11         Poltava     29
# 12           Rivne     10
# 13            Sumy    349
# 14        Ternopil      3
# 15     Zakarpattia      1
# 16       Vinnytsia     17
# 17           Volyn      4
# 18        Zhytomyr     39

# %%
fig, ax = plt.subplots(1, figsize=(12, 12))

ukraine_map_merged.plot(
    column="count", cmap="Reds", linewidth=0.4, ax=ax, edgecolor=".4"
)
# Out:
# <Axes: >

# %%
ukraine_map
# Out:
#    GID_0   NAME_0     GID_1            NAME_1  \
# 0    UKR  Ukraine   UKR.1_1          Cherkasy
# 1    UKR  Ukraine   UKR.2_1         Chernihiv
# 2    UKR  Ukraine   UKR.3_1        Chernivtsi
# 3    UKR  Ukraine   UKR.4_1            Crimea
# 4    UKR  Ukraine   UKR.5_1    Dnipropetrovsk
# 5    UKR  Ukraine   UKR.6_1           Donetsk
# 6    UKR  Ukraine   UKR.7_1  Ivano-Frankivs'k
# 7    UKR  Ukraine   UKR.8_1           Kharkiv
# 8    UKR  Ukraine   UKR.9_1           Kherson
# 9    UKR  Ukraine  UKR.10_1      Khmelnytskyi
# 10   UKR  Ukraine  UKR.12_1              Kyiv
# 11   UKR  Ukraine  UKR.11_1         Kiev City
# 12   UKR  Ukraine  UKR.13_1        Kirovohrad
# 13   UKR  Ukraine  UKR.14_1              Lviv
# 14   UKR  Ukraine  UKR.15_1           Luhansk
# 15   UKR  Ukraine  UKR.16_1         Mykolayiv
# 16   UKR  Ukraine  UKR.17_1             Odesa
# 17   UKR  Ukraine  UKR.18_1           Poltava
# 18   UKR  Ukraine  UKR.19_1             Rivne
# 19   UKR  Ukraine  UKR.20_1       Sevastopol'
# 20   UKR  Ukraine  UKR.21_1              Sumy
# 21   UKR  Ukraine  UKR.22_1          Ternopil
# 22   UKR  Ukraine  UKR.23_1       Zakarpattia
# 23   UKR  Ukraine  UKR.24_1         Vinnytsia
# 24   UKR  Ukraine  UKR.25_1             Volyn
# 25   UKR  Ukraine  UKR.26_1      Zaporizhzhya
# 26   UKR  Ukraine  UKR.27_1          Zhytomyr
#
#                                             VARNAME_1  NL_NAME_1  \
# 0   Cherkas'ka Oblast'|Cherkasskaya Oblast'|Cherkassy        NaN
# 1                               Chernigov|Tschernigow        NaN
# 2   Chernivets'ka Oblast'|Chernovitskaya Oblast'|C...        NaN
# 3   Crimée|Criméia|Krim|Krymskaya Respublika|Respu...        NaN
# 4     Dnipropetrovsk|Dniepropietrovsk|Dnjepropetrowsk        NaN
# 5           Donetsk|Donetskaya Oblast'|Donezk|Stalino        NaN
# 6   Ivano-Frankovsk|Ivano-Frankovskaya Oblast'|Sta...        NaN
# 7                      Charkow|Jarkov|Karkov|Khar'kov        NaN
# 8                         Cherson|Khersons'ka Oblast'        NaN
# 9   Khmelnitsky|Khmelnytskyi|Chmelnizkij|Hmelnicki...        NaN
# 10  Kiev Oblast|Kiew|Kijew|Kiiv|Kijev|Kiyev|Kyiv|K...        NaN
# 11                                               Kyiv        NaN
# 12                 Kirovograd|Kirovogradskaya Oblast'        NaN
# 13         Lemberg|Llvov|L'vov|Lwow|L'vivs'ka Oblast'        NaN
# 14   Luhansk|Lugansk|Luhans'ka Oblast'|Voroshilovgrad        NaN
# 15                       Mykolaiv|Nikolajew|Nikolayev        NaN
# 16            Odesa|Odes'ka Oblast'|Odesskaya Oblast'        NaN
# 17                                                NaN        NaN
# 18        Rovno|Rivnens'ka Oblast'|Rovenskaya Oblast'        NaN
# 19                                         Sebastopol        NaN
# 20                                                NaN        NaN
# 21                                 Ternopol|Ternopol'        NaN
# 22  Transcarpathian|Zakarpattia|Ruthenia|Zakarpats...        NaN
# 23  Vinnytsia|Vinnitskaya Oblast'|Vinnyts'ka Oblas...        NaN
# 24  Volhynia|Volyns'ka Oblast'|Volynskaya Oblast'|...        NaN
# 25  Saporoshje|Zaporizhia|Zaporiz'ka Oblast'|Zapor...        NaN
# 26    Zhitomir|Jitomir|Shitomir|Zhitomirskaya Oblast'        NaN
#
#                  TYPE_1            ENGTYPE_1  CC_1 HASC_1  \
# 0               Oblast'               Region   NaN  UA.CK
# 1               Oblast'               Region   NaN  UA.CH
# 2               Oblast'               Region   NaN  UA.CV
# 3   Autonomous Republic  Autonomous Republic   NaN  UA.KR
# 4               Oblast'               Region   NaN  UA.DP
# 5               Oblast'               Region   NaN  UA.DT
# 6               Oblast'               Region   NaN  UA.IF
# 7               Oblast'               Region   NaN  UA.KK
# 8               Oblast'               Region   NaN  UA.KS
# 9               Oblast'               Region   NaN  UA.KM
# 10              Oblast'               Region   NaN  UA.KV
# 11     Independent City     Independent City   NaN  UA.KC
# 12              Oblast'               Region   NaN  UA.KH
# 13              Oblast'               Region   NaN  UA.LV
# 14              Oblast'               Region   NaN  UA.LH
# 15              Oblast'               Region   NaN  UA.MY
# 16              Oblast'               Region   NaN  UA.OD
# 17              Oblast'               Region   NaN  UA.PL
# 18              Oblast'               Region   NaN  UA.RV
# 19  Autonomous Republic  Autonomous Republic   NaN  UA.SC
# 20              Oblast'               Region   NaN  UA.SM
# 21              Oblast'               Region   NaN  UA.TP
# 22              Oblast'               Region   NaN  UA.ZK
# 23              Oblast'               Region   NaN  UA.VI
# 24              Oblast'               Region   NaN  UA.VO
# 25              Oblast'               Region   NaN  UA.ZP
# 26              Oblast'               Region   NaN  UA.ZT
#
#                                              geometry            region
# 0   POLYGON ((31.32614 48.74507, 31.31716 48.74512...          Cherkasy
# 1   POLYGON ((33.09283 50.50966, 33.09261 50.49788...         Chernihiv
# 2   POLYGON ((24.93280 47.72794, 24.93301 47.72995...        Chernivtsi
# 3   MULTIPOLYGON (((33.79291 44.39153, 33.79465 44...            Crimea
# 4   POLYGON ((33.93176 47.48407, 33.92332 47.49026...    Dnipropetrovsk
# 5   MULTIPOLYGON (((37.67542 47.08208, 37.67542 47...           Donetsk
# 6   POLYGON ((24.48985 48.29008, 24.47929 48.30110...  Ivano-Frankivs'k
# 7   POLYGON ((36.73418 48.61828, 36.71661 48.61870...           Kharkiv
# 8   MULTIPOLYGON (((31.96903 46.20319, 31.96903 46...           Kherson
# 9   POLYGON ((26.43747 48.53564, 26.43671 48.54154...      Khmelnytskyi
# 10  POLYGON ((29.74569 49.24075, 29.72713 49.25809...              Kyiv
# 11  POLYGON ((30.73957 50.49034, 30.73972 50.48669...         Kiev City
# 12  POLYGON ((31.82397 47.79166, 31.83274 47.79161...        Kirovohrad
# 13  MULTIPOLYGON (((23.96410 50.41843, 23.96423 50...              Lviv
# 14  POLYGON ((39.91058 48.16798, 39.90993 48.16432...           Luhansk
# 15  MULTIPOLYGON (((31.41125 46.60264, 31.41125 46...         Mykolayiv
# 16  MULTIPOLYGON (((30.20708 45.25764, 30.20708 45...             Odesa
# 17  POLYGON ((35.51211 49.55266, 35.46757 49.55336...           Poltava
# 18  POLYGON ((26.30246 50.20480, 26.29387 50.19846...             Rivne
# 19  POLYGON ((33.80236 44.39421, 33.80236 44.39431...       Sevastopol'
# 20  POLYGON ((34.96434 50.14548, 34.94647 50.14563...              Sumy
# 21  POLYGON ((26.20062 48.91127, 26.20966 48.91165...          Ternopil
# 22  POLYGON ((23.89934 47.94503, 23.89867 47.94472...       Zakarpattia
# 23  POLYGON ((29.96737 48.61654, 29.96781 48.60485...         Vinnytsia
# 24  POLYGON ((24.58838 50.44717, 24.58535 50.47087...             Volyn
# 25  MULTIPOLYGON (((35.05986 46.15125, 35.05986 46...      Zaporizhzhya
# 26  POLYGON ((29.46955 49.81223, 29.46984 49.80634...          Zhytomyr

# %%
df_final_pkl
# Out:
#            date             city   region      lat      lng  \
# 0    2022-03-02        [Kharkiv]  Kharkiv  50.0000  36.2292
# 1    2022-03-03            [nan]     Kyiv  50.4500  30.5236
# 2    2022-03-02  [Severodonetsk]  Donetsk  48.9482  38.4879
# 3    2022-03-03           [Kyiv]     Kyiv  50.4500  30.5236
# 4    2022-03-02        [Kharkiv]  Kharkiv  50.0000  36.2292
# ...         ...              ...      ...      ...      ...
# 8789 2023-02-15            [nan]  Donetsk  48.0089  37.8042
# 8790 2023-02-15            [nan]  Kharkiv  50.0000  36.2292
# 8791 2023-02-15            [nan]  Kharkiv  50.0000  36.2292
# 8792 2023-02-15       [Pokrovsk]  Donetsk  48.2833  37.1833
# 8793 2023-02-15            [nan]  Donetsk  48.0089  37.8042
#
#                                                 content  \
# 0                        Kharkiv Missile striked school
# 1     Hatne Kyiv region due to a powerful airstrike ...
# 2     Donetsk region Severodonetsk Kindergarten was ...
# 3                       Kyiv russian cruise missile TAG
# 4        Kharkiv Consequences of airstrike on city hall
# ...                                                 ...
# 8789  Donetsk region Residential high-rise buildings...
# 8790  Kharkiv region Private houses, households dama...
# 8791  Kharkiv region Private houses, households dama...
# 8792  Pokrovsk Donetsk region Residential high-rise ...
# 8793  Chasiv Yar Donetsk region Humanitarian headqua...
#
#                        geometry
# 0     POINT (36.22920 50.00000)
# 1     POINT (30.52360 50.45000)
# 2     POINT (38.48790 48.94820)
# 3     POINT (30.52360 50.45000)
# 4     POINT (36.22920 50.00000)
# ...                         ...
# 8789  POINT (37.80420 48.00890)
# 8790  POINT (36.22920 50.00000)
# 8791  POINT (36.22920 50.00000)
# 8792  POINT (37.18330 48.28330)
# 8793  POINT (37.80420 48.00890)
#
# [8794 rows x 7 columns]

# %%
ukraine_map["strike_count"] = 0
for index, row in df_final_pkl.iterrows():
  if row["geometry"].is_empty:
    continue
  index = ukraine_map.index[ukraine_map["geometry"].contains(row["geometry"])][0]
  ukraine_map.loc[index, "strike_count"] += 1

# %%
ukraine_map["strike_count"]
# Out:
# 0        2
# 1      162
# 2        5
# 3       15
# 4      667
# 5     2535
# 6       12
# 7     1402
# 8      349
# 9       10
# 10     352
# 11     529
# 12      12
# 13     119
# 14     439
# 15     633
# 16     132
# 17      33
# 18      10
# 19       0
# 20     330
# 21       3
# 22       5
# 23      58
# 24      11
# 25     716
# 26      53
# Name: strike_count, dtype: int64

# %%
fig, ax = plt.subplots(1, figsize=(12, 12))
ukraine_map.plot(
    column="strike_count", cmap="Reds", linewidth=0.4, ax=ax, edgecolor=".4"
)
# Out:
# <Axes: >

# %%
df_final_pkl
counts = df_final_pkl.groupby(['region']).size()
counts.plot(kind='bar', stacked=True, figsize=(10, 8))
# Out:
# <Axes: xlabel='region'>

# %%
import seaborn as sns
colors = sns.color_palette('pastel')
counts = df_final_pkl['region'].value_counts()
frequency_sorted = counts.sort_values(ascending=False)
top_5 = frequency_sorted[:5]
other = pd.Series(frequency_sorted[5:].sum(), index=['Other'])
new_series = top_5.append(other)
percentages = (new_series / new_series.sum()) * 100
plt.pie(percentages, colors=colors, labels=percentages.index, autopct='%.0f %%')
plt.title('Top 5 regions by incidents')
plt.show()
# Out:
# <ipython-input-50-7f7559d1c231>:7: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_series = top_5.append(other)
